# %%
# !pip install requests
# !pip install pmdarima

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from pmdarima.arima import auto_arima

# Replace 'YOUR_API_KEY' with your actual CoinMarketCap API key
api_key = '60af4540-7f81-486e-9635-8a3ae482e4ab'

# URL for the CoinMarketCap API endpoint you want to access
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

# Parameters for your API request (you can customize these)
parameters = {
    'start':'1',
    'limit':'10',  # Change this to the number of cryptocurrencies you want to analyze
    'convert':'USD'  # Change this to your preferred currency if different from USD
}

# Include your API key in the request headers
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': api_key,
}

# Make the API request
response = requests.get(url, headers=headers, params=parameters)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    print(data)

    # Now, 'data' contains the cryptocurrency information from the API response
    # You can start analyzing the data from here
else:
    # If the request was not successful, print an error message
    print('Error:', response.status_code)
# Out:
# {'status': {'timestamp': '2023-10-30T20:22:31.472Z', 'error_code': 0, 'error_message': None, 'elapsed': 29, 'credit_count': 1, 'notice': None, 'total_count': 8824}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10513, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
# Assuming 'data' contains the API response data
cryptocurrencies = data['data']

# Sort cryptocurrencies by market capitalization
sorted_cryptos = sorted(cryptocurrencies, key=lambda x: x['quote']['USD']['market_cap'], reverse=True)

# Extract and print information about the top 5 cryptocurrencies
top_5_cryptos = sorted_cryptos[:5]
for crypto in top_5_cryptos:
    name = crypto['name']
    symbol = crypto['symbol']
    market_cap = crypto['quote']['USD']['market_cap']
    price = crypto['quote']['USD']['price']
    volume_24h = crypto['quote']['USD']['volume_24h']
    print(f"{name} ({symbol}) - Market Cap: {market_cap}, Price: {price}, 24h Volume: {volume_24h}")
# Out:
# Bitcoin (BTC) - Market Cap: 671075373377.1981, Price: 34363.83244567671, 24h Volume: 17320465059.356873
# Ethereum (ETH) - Market Cap: 216323655011.46533, Price: 1798.656328743788, 24h Volume: 7550279704.630841
# Tether USDt (USDT) - Market Cap: 84584959357.31938, Price: 1.0005541398950206, 24h Volume: 28557975028.14662
# BNB (BNB) - Market Cap: 34576138675.035576, Price: 227.91872865399299, 24h Volume: 280698352.5235213
# XRP (XRP) - Market Cap: 31112820946.77735, Price: 0.5808910686060059, 24h Volume: 1474682991.773711

# %%
# Assuming 'data' contains the API response data
cryptocurrencies = data['data']

# Sort cryptocurrencies by market capitalization
sorted_cryptos = sorted(cryptocurrencies, key=lambda x: x['quote']['USD']['market_cap'], reverse=True)

# Extract data for the top 5 cryptocurrencies
top_5_cryptos = sorted_cryptos[:5]
names = [crypto['name'] for crypto in top_5_cryptos]
market_caps = [crypto['quote']['USD']['market_cap'] for crypto in top_5_cryptos]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(names, market_caps, color='skyblue')
plt.xlabel('Cryptocurrency')
plt.ylabel('Market Capitalization (USD)')
plt.title('Top 5 Cryptocurrencies by Market Cap')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.tight_layout()

# Show the bar chart
plt.show()

# %%
# Data for the top five cryptocurrencies
cryptos = [
    {'name': 'Bitcoin', 'volume_24h': 28522615226.00617},
    {'name': 'Ethereum', 'volume_24h': 9050913968.262241},
    {'name': 'Tether USDt', 'volume_24h': 49422987071.77296},
    {'name': 'BNB', 'volume_24h': 517977849.19039303},
    {'name': 'XRP', 'volume_24h': 1103199725.7053185}
]

# Extracting names and volumes
names = [crypto['name'] for crypto in cryptos]
volumes = [crypto['volume_24h'] for crypto in cryptos]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.bar(names, volumes, color='skyblue')
plt.xlabel('Cryptocurrency')
plt.ylabel('Volume (USD)')
plt.title('Top 5 Cryptocurrencies by Volume (Past 7 Days)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
